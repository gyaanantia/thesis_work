# %%
import pandas as pd

# %%
data = pd.read_csv('rewards.csv')
data.head()
# Out:
#    Step  \
# 0   200
# 1   400
# 2   600
# 3   800
# 4  1000
#
#    GOOD-rmappo-sd-beta-add-id-20240520-150835-seed1 - average_episode_rewards  \
# 0                                          -3.587499
# 1                                           2.962500
# 2                                           2.962501
# 3                                           3.600001
# 4                                           3.924999
#
#    GOOD-rmappo-sd-beta-add-id-20240520-150835-seed1 - average_episode_rewards__MIN  \
# 0                                          -3.587499
# 1                                           2.962500
# 2                                           2.962501
# 3                                           3.600001
# 4                                           3.924999
#
#    GOOD-rmappo-sd-beta-add-id-20240520-150835-seed1 - average_episode_rewards__MAX
# 0                                          -3.587499
# 1                                           2.962500
# ...

# %%
data.plot(x='Step', y='GOOD-rmappo-sd-beta-add-id-20240520-150835-seed1 - average_episode_rewards', kind='line')
# Out:
# <Axes: xlabel='Step'>
