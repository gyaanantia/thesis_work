# %% [markdown]
# # MAPPO Integration
#
# This runs the integrated MAPPO algorithm with the patrolling zoo.

# %%
# %reload_ext autoreload
# %autoreload 2
from onpolicy.scripts.train.train_sd import get_config, parse_args, main

import os
os.environ["WANDB__SERVICE_WAIT"] = "300"

# %%
import numpy as np

parser = get_config()
all_args = parse_args([], parser)

all_args.experiment_name = "metric-test"
all_args.env_name = "search-deliver"
all_args.user_name = "ideas-mas"

all_args.num_agents = 4
all_args.agent_speed = 40.0
all_args.action_method = "neighbors"
all_args.observe_method = "pyg"
all_args.observe_method_global = "adjacency"
all_args.observation_radius = 40.0
all_args.observation_bitmap_size = 40
all_args.communication_model = "bernoulli"
all_args.communication_probability = 1.0
all_args.alpha = 1.2
all_args.beta = 1.0


all_args.drop_reward = 1.0
all_args.load_reward = 1.0
all_args.step_reward = 0.0
all_args.state_reward = 1.0
all_args.agent_max_capacity = 1
# all_args.reward_method_terminal = "averageAverage"
all_args.reward_method_terminal = "average"
# all_args.reward_interval = 1

# all_args.graph_random = True
# all_args.graph_random_nodes = 9
all_args.graph_name = "9nodes"
all_args.graph_file = f"../../../sdzoo/env/{all_args.graph_name}.graph"
# all_args.num_env_steps = 10000 #total number of steps
all_args.num_env_steps = 5000 #1e5 * 2.5 #total number of steps
all_args.episode_length = 20 #number of steps in a training episode
all_args.max_cycles = all_args.episode_length #number of steps in an environment episode

all_args.algorithm_name = "rmappo"
all_args.use_gnn_policy = True
all_args.use_gnn_mlp_policy = True
all_args.gnn_layer_N = 6
all_args.gnn_hidden_size = 128
all_args.gnn_skip_connections = True
all_args.use_recurrent_policy = True
all_args.use_naive_recurrent_policy = False
all_args.use_centralized_V = True
all_args.use_gae = False
all_args.use_gae_amadm = True
all_args.share_policy = True
all_args.sep_share_policy = False
all_args.share_reward = False
all_args.skip_steps_sync = True # these need to be false to use max cycles
all_args.skip_steps_async = False
all_args.use_ReLU = True
# all_args.lr = 1e-3
# all_args.entropy_coef = 0.1
all_args.hidden_size = 512

all_args.n_rollout_threads = 1
all_args.save_interval = 1000
all_args.cuda = False
all_args.cuda_idx = 3

all_args.use_wandb = False

# %%
main([], parsed_args = all_args)
# Out:
# u are choosing to use rmappo, we set use_recurrent_policy to be True
# choose to use cpu...
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 2
# Agent 2 Payloads: 1
# Agent 2 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 0/250 episodes, total num timesteps 20/5000, FPS 2.
#
# average episode rewards is -0.4475000500679016
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 2
# Agent 2 Payloads: 0
# Agent 2 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 3
# Agent 3 Payloads: 1
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 1/250 episodes, total num timesteps 40/5000, FPS 2.
#
# average episode rewards is -0.572500005364418
# Total Deficit: 25
# Total Surplus: 23
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 23
# AGENT ID: 1
# Agent 1 Payloads: 1
# Agent 1 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 23
# AGENT ID: 2
# Agent 2 Payloads: 1
# Agent 2 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 23
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 2/250 episodes, total num timesteps 60/5000, FPS 2.
#
# average episode rewards is -0.8000000566244125
# Total Deficit: 25
# Total Surplus: 25
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 25
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 25
# AGENT ID: 2
# Agent 2 Payloads: 0
# Agent 2 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 25
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 3/250 episodes, total num timesteps 80/5000, FPS 2.
#
# average episode rewards is -0.9250000864267349
# Total Deficit: 24
# Total Surplus: 22
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 22
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 22
# AGENT ID: 2
# Agent 2 Payloads: 1
# Agent 2 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 22
# AGENT ID: 3
# Agent 3 Payloads: 1
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 4/250 episodes, total num timesteps 100/5000, FPS 2.
#
# average episode rewards is -0.4349999874830246
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 2
# Agent 2 Payloads: 1
# Agent 2 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 5/250 episodes, total num timesteps 120/5000, FPS 2.
#
# average episode rewards is -0.42249999940395355
# Total Deficit: 23
# Total Surplus: 23
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 23
# Total Surplus: 23
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 23
# Total Surplus: 23
# AGENT ID: 2
# Agent 2 Payloads: 0
# Agent 2 Max Capacity: 1
# Total Deficit: 23
# Total Surplus: 23
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 6/250 episodes, total num timesteps 140/5000, FPS 2.
#
# average episode rewards is -0.2200000360608101
# Total Deficit: 23
# Total Surplus: 21
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 23
# Total Surplus: 21
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 23
# Total Surplus: 21
# AGENT ID: 2
# Agent 2 Payloads: 1
# Agent 2 Max Capacity: 1
# Total Deficit: 23
# Total Surplus: 21
# AGENT ID: 3
# Agent 3 Payloads: 1
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 7/250 episodes, total num timesteps 160/5000, FPS 2.
#
# average episode rewards is -0.007499873754568398
# Total Deficit: 24
# Total Surplus: 21
# AGENT ID: 0
# Agent 0 Payloads: 1
# Agent 0 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 21
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 21
# AGENT ID: 2
# Agent 2 Payloads: 1
# Agent 2 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 21
# AGENT ID: 3
# Agent 3 Payloads: 1
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 8/250 episodes, total num timesteps 180/5000, FPS 2.
#
# average episode rewards is -0.34749992191791534
# Total Deficit: 23
# Total Surplus: 22
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 23
# Total Surplus: 22
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 23
# Total Surplus: 22
# AGENT ID: 2
# Agent 2 Payloads: 1
# Agent 2 Max Capacity: 1
# Total Deficit: 23
# Total Surplus: 22
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 9/250 episodes, total num timesteps 200/5000, FPS 2.
#
# average episode rewards is -0.1325000822544098
# Total Deficit: 25
# Total Surplus: 22
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 22
# AGENT ID: 1
# Agent 1 Payloads: 1
# Agent 1 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 22
# AGENT ID: 2
# Agent 2 Payloads: 1
# Agent 2 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 22
# AGENT ID: 3
# Agent 3 Payloads: 1
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 10/250 episodes, total num timesteps 220/5000, FPS 2.
#
# average episode rewards is -0.7874999940395355
# Total Deficit: 23
# Total Surplus: 21
# AGENT ID: 0
# Agent 0 Payloads: 1
# Agent 0 Max Capacity: 1
# Total Deficit: 23
# Total Surplus: 21
# AGENT ID: 1
# Agent 1 Payloads: 1
# Agent 1 Max Capacity: 1
# Total Deficit: 23
# Total Surplus: 21
# AGENT ID: 2
# Agent 2 Payloads: 0
# Agent 2 Max Capacity: 1
# Total Deficit: 23
# Total Surplus: 21
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 11/250 episodes, total num timesteps 240/5000, FPS 2.
#
# average episode rewards is 0.08000001311302185
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 2
# Agent 2 Payloads: 0
# Agent 2 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 23
# AGENT ID: 3
# Agent 3 Payloads: 1
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 12/250 episodes, total num timesteps 260/5000, FPS 2.
#
# average episode rewards is -0.17249997705221176
# Total Deficit: 22
# Total Surplus: 20
# AGENT ID: 0
# Agent 0 Payloads: 1
# Agent 0 Max Capacity: 1
# Total Deficit: 22
# Total Surplus: 20
# AGENT ID: 1
# Agent 1 Payloads: 1
# Agent 1 Max Capacity: 1
# Total Deficit: 22
# Total Surplus: 20
# AGENT ID: 2
# Agent 2 Payloads: 0
# Agent 2 Max Capacity: 1
# Total Deficit: 22
# Total Surplus: 20
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 13/250 episodes, total num timesteps 280/5000, FPS 2.
#
# average episode rewards is 0.6700001657009125
# Total Deficit: 22
# Total Surplus: 21
# AGENT ID: 0
# Agent 0 Payloads: 1
# Agent 0 Max Capacity: 1
# Total Deficit: 22
# Total Surplus: 21
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 22
# Total Surplus: 21
# AGENT ID: 2
# Agent 2 Payloads: 0
# Agent 2 Max Capacity: 1
# Total Deficit: 22
# Total Surplus: 21
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 14/250 episodes, total num timesteps 300/5000, FPS 2.
#
# average episode rewards is 0.39499998092651367
# Total Deficit: 21
# Total Surplus: 20
# AGENT ID: 0
# Agent 0 Payloads: 1
# Agent 0 Max Capacity: 1
# Total Deficit: 21
# Total Surplus: 20
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 21
# Total Surplus: 20
# AGENT ID: 2
# Agent 2 Payloads: 0
# Agent 2 Max Capacity: 1
# Total Deficit: 21
# Total Surplus: 20
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 15/250 episodes, total num timesteps 320/5000, FPS 2.
#
# average episode rewards is 0.8474999666213989
# Total Deficit: 25
# Total Surplus: 25
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 25
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 25
# AGENT ID: 2
# Agent 2 Payloads: 0
# Agent 2 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 25
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 16/250 episodes, total num timesteps 340/5000, FPS 2.
#
# average episode rewards is -0.5750000476837158
# Total Deficit: 25
# Total Surplus: 23
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 23
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 23
# AGENT ID: 2
# Agent 2 Payloads: 1
# Agent 2 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 23
# AGENT ID: 3
# Agent 3 Payloads: 1
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 17/250 episodes, total num timesteps 360/5000, FPS 2.
#
# average episode rewards is -0.5000000074505806
# Total Deficit: 25
# Total Surplus: 24
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 24
# AGENT ID: 1
# Agent 1 Payloads: 1
# Agent 1 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 24
# AGENT ID: 2
# Agent 2 Payloads: 0
# Agent 2 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 24
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 18/250 episodes, total num timesteps 380/5000, FPS 2.
#
# average episode rewards is -0.637500062584877
# Total Deficit: 24
# Total Surplus: 24
# AGENT ID: 0
# Agent 0 Payloads: 0
# Agent 0 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 24
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 24
# AGENT ID: 2
# Agent 2 Payloads: 0
# Agent 2 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 24
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 19/250 episodes, total num timesteps 400/5000, FPS 2.
#
# average episode rewards is -0.03500002669170499
# Total Deficit: 25
# Total Surplus: 23
# AGENT ID: 0
# Agent 0 Payloads: 1
# Agent 0 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 23
# AGENT ID: 1
# Agent 1 Payloads: 1
# Agent 1 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 23
# AGENT ID: 2
# Agent 2 Payloads: 0
# Agent 2 Max Capacity: 1
# Total Deficit: 25
# Total Surplus: 23
# AGENT ID: 3
# Agent 3 Payloads: 0
# Agent 3 Max Capacity: 1
#
#  Env search-deliver Algo rmappo Exp metric-test updates 20/250 episodes, total num timesteps 420/5000, FPS 2.
#
# average episode rewards is -0.20000001415610313
# Total Deficit: 24
# Total Surplus: 22
# AGENT ID: 0
# Agent 0 Payloads: 1
# Agent 0 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 22
# AGENT ID: 1
# Agent 1 Payloads: 0
# Agent 1 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 22
# AGENT ID: 2
# Agent 2 Payloads: 0
# Agent 2 Max Capacity: 1
# Total Deficit: 24
# Total Surplus: 22
# AGENT ID: 3
# Agent 3 Payloads: 1
# Agent 3 Max Capacity: 1
