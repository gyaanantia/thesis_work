# %% [markdown]
# # MAPPO Evaluation & Rendering
#
# This runs the trained MAPPO policy with the patrolling zoo.

# %%
# %reload_ext autoreload
# %autoreload 2
from onpolicy.scripts.render.render_patrolling import get_config, parse_args, main

import os
import yaml
os.environ["WANDB__SERVICE_WAIT"] = "300"

# %% [markdown]
# ## Configuration

# %%
# Set the run directory.
model_dir = "/home/gyaan/data/sdzoo/onpolicy/scripts/results/search-deliver/9nodes/mappo/search-and-deliver-alpha-communicate-lastNode-currentAction/wandb/run-20240508_203838-5o9qfq5g/files"

# %%
# Load the default arguments.
parser = get_config()
all_args = parse_args([], parser)

# Load new arguments from the config file.
config_file = os.path.join(model_dir, "config.yaml")
args = yaml.load(open(config_file), Loader=yaml.FullLoader)

# Convert the arguments to a Namespace object.
for a in args:
    if type(args[a]) == dict and "value" in args[a]:
        args[a] = args[a]["value"]
for a in args:
    setattr(all_args, a, args[a])

# Set required render-specific arguments. Do not change these!
all_args.use_wandb = False
all_args.use_render = True
all_args.model_dir = model_dir
all_args.cuda = False

# %%
# Feel free to change these arguments.
all_args.render_episodes = 1
# all_args.episode_length = 500
# all_args.max_cycles = all_args.episode_length

# all_args.skip_steps_sync = False
# all_args.agent_speed = 20.0
all_args.num_agents = 4
# all_args.observation_radius = 9999999
# all_args.graph_random = True
# all_args.graph_random_nodes = 42

# all_args.attrition_method = "fixed_time"
# all_args.attrition_fixed_times = [300, 1100]

all_args.graph_name = "9nodes"
all_args.graph_file = f"../../../sdzoo/env/{all_args.graph_name}.graph"

# %% [markdown]
# ## Perform Rendering

# %%
main([], parsed_args = all_args)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 main([], parsed_args = all_args)
#
# File /data/gyaan/sdzoo/onpolicy/scripts/render/render_patrolling.py:107, in main(args, parsed_args)
#     104     from onpolicy.runner.separated.patrolling_runner import PatrollingRunner as Runner
#     106 runner = Runner(config)
# --> 107 runner.render()
#     109 # post process
#     110 envs.close()
#
# File ~/anaconda3/envs/sdzoo/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /data/gyaan/sdzoo/onpolicy/runner/shared/patrolling_runner.py:314, in PatrollingRunner.render(self, ipython_clear_output)
#     312     if ipython_clear_output:
#     313         clear_output(wait = True)
# --> 314     render_env.envs[0].env.render()
#     316 # append frame
#     317 if self.all_args.save_gifs:
#
# File /data/gyaan/sdzoo/sdzoo/env/sdzoo.py:365, in parallel_env.render(self, figsize)
#     363 state = [self.sdg.getNodeDeficit(i) for i in self.sdg.graph.nodes]
#     364 labels = {n: f"{n}\n{self.sdg.getNodePeople(n)},{self.sdg.getNodePayloads(n)}" for n in self.sdg.graph.nodes}
# --> 365 nx.draw_networkx(self.sdg.graph,
#     366                  pos,
#     367                  with_labels=True,
#     368                  labels=labels,
#     369                  node_color=state,
#     370                  edgecolors='black',
#     371                  vmin=0,
#     372                  vmax=100,
#     373                  cmap='Purples',
#     374                  node_size=600,
#     375                  font_size=10,
#     376                  font_color='black'
#     377 )
#     378 weights = {key: np.round(value, 1) for key, value in nx.get_edge_attributes(self.sdg.graph, 'weight').items()}
#     379 nx.draw_networkx_edge_labels(self.sdg.graph, pos, edge_labels=weights, font_size=7)
#
# File ~/anaconda3/envs/sdzoo/lib/python3.10/site-packages/networkx/drawing/nx_pylab.py:304, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     301     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     303 draw_networkx_nodes(G, pos, **node_kwds)
# --> 304 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#     305 if with_labels:
#     306     draw_networkx_labels(G, pos, **label_kwds)
#
# File ~/anaconda3/envs/sdzoo/lib/python3.10/site-packages/networkx/drawing/nx_pylab.py:896, in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin)
#     894 # Draw the edges
#     895 if use_linecollection:
# --> 896     edge_viz_obj = _draw_networkx_edges_line_collection()
#     897     # Make sure selfloop edges are also drawn
#     898     selfloops_to_draw = [loop for loop in nx.selfloop_edges(G) if loop in edgelist]
#
# File ~/anaconda3/envs/sdzoo/lib/python3.10/site-packages/networkx/drawing/nx_pylab.py:750, in draw_networkx_edges.<locals>._draw_networkx_edges_line_collection()
#     748 edge_collection.set_zorder(1)  # edges go behind nodes
#     749 edge_collection.set_label(label)
# --> 750 ax.add_collection(edge_collection)
#     752 return edge_collection
#
# File ~/anaconda3/envs/sdzoo/lib/python3.10/site-packages/matplotlib/axes/_base.py:2269, in _AxesBase.add_collection(self, collection, autolim)
#    2265 if autolim:
#    2266     # Make sure viewLim is not stale (mostly to match
#    2267     # pre-lazy-autoscale behavior, which is not really better).
#    2268     self._unstale_viewLim()
# -> 2269     datalim = collection.get_datalim(self.transData)
#    2270     points = datalim.get_points()
#    2271     if not np.isinf(datalim.minpos).all():
#    2272         # By definition, if minpos (minimum positive value) is set
#    2273         # (i.e., non-inf), then min(points) <= minpos <= max(points),
#    2274         # and minpos would be superfluous. However, we add minpos to
#    2275         # the call so that self.dataLim will update its own minpos.
#    2276         # This ensures that log scales see the correct minimum.
#
# File ~/anaconda3/envs/sdzoo/lib/python3.10/site-packages/matplotlib/collections.py:283, in Collection.get_datalim(self, transData)
#     281         offsets = offsets.filled(np.nan)
#     282         # get_path_collection_extents handles nan but not masked arrays
# --> 283     return mpath.get_path_collection_extents(
#     284         transform.get_affine() - transData, paths,
#     285         self.get_transforms(),
#     286         offset_trf.transform_non_affine(offsets),
#     287         offset_trf.get_affine().frozen())
#     289 # NOTE: None is the default case where no offsets were passed in
#     290 if self._offsets is not None:
#     291     # this is for collections that have their paths (shapes)
#     292     # in physical, axes-relative, or figure-relative units
#     293     # (i.e. like scatter). We can't uniquely set limits based on
#     294     # those shapes, so we just set the limits based on their
#     295     # location.
#
# File ~/anaconda3/envs/sdzoo/lib/python3.10/site-packages/matplotlib/path.py:1090, in get_path_collection_extents(master_transform, paths, transforms, offsets, offset_transform)
#    1085 if len(offsets) == 0:
#    1086     _api.warn_deprecated(
#    1087         "3.8", message="Calling get_path_collection_extents() with an"
#    1088         " empty offsets list is deprecated since %(since)s. Support will"
#    1089         " be removed %(removal)s.")
# -> 1090 extents, minpos = _path.get_path_collection_extents(
#    1091     master_transform, paths, np.atleast_3d(transforms),
#    1092     offsets, offset_transform)
#    1093 return Bbox.from_extents(*extents, minpos=minpos)
#
# File ~/anaconda3/envs/sdzoo/lib/python3.10/site-packages/matplotlib/transforms.py:1773, in AffineBase.__array__(self, *args, **kwargs)
#    1770     super().__init__(*args, **kwargs)
#    1771     self._inverted = None
# -> 1773 def __array__(self, *args, **kwargs):
#    1774     # optimises the access of the transform matrix vs. the superclass
#    1775     return self.get_matrix()
#    1777 def __eq__(self, other):
#
# KeyboardInterrupt:
